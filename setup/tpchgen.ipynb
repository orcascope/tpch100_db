# %%
# !pip install tpchgen-cli==2.0.1
# %restart_python

# %%
# !tpchgen-cli --scale-factor=100 -T lineitem -f parquet -p 160 --output-dir=/Volumes/workspace/default/files -v

# %%
# !tpchgen-cli --scale-factor=100 -T nation -f parquet -p 20 --output-dir=/Volumes/workspace/default/files -v

# %%
# !tpchgen-cli --scale-factor=100 -T region -f parquet -p 20 --output-dir=/Volumes/workspace/default/files -v

# %%
# !tpchgen-cli --scale-factor=100 -T part -f parquet -p 20 --output-dir=/Volumes/workspace/default/files -v

# %%
# !tpchgen-cli --scale-factor=100 -T supplier -f parquet -p 20 --output-dir=/Volumes/workspace/default/files -v

# %%
# !tpchgen-cli --scale-factor=100 -T partsupp -f parquet -p 20 --output-dir=/Volumes/workspace/default/files -v

# %%
# !tpchgen-cli --scale-factor=100 -T customer -f parquet -p 20 --output-dir=/Volumes/workspace/default/files -v

# %%
# !tpchgen-cli --scale-factor=100 -T orders -f parquet -p 20 --output-dir=/Volumes/workspace/default/files -v
